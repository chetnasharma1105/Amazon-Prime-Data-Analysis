# %% [markdown]
# # Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statistics

# %% [markdown]
# # Importing the CSV files and inspecting them

# %%
titles = pd.read_csv("titles.csv")

# %%
titles.head()
# Out:
#          id                  title   type  \
# 0   tm87233  It's a Wonderful Life  MOVIE
# 1  tm143047              Duck Soup  MOVIE
# 2   tm83884        His Girl Friday  MOVIE
# 3   ts20945      The Three Stooges   SHOW
# 4    tm5012              Red River  MOVIE
#
#                                          description  release_year  \
# 0  A holiday favourite for generations...  George...          1946
# 1  Rufus T. Firefly is named president/dictator o...          1933
# 2  Hildy, the journalist former wife of newspaper...          1940
# 3  The Three Stooges were an American vaudeville ...          1934
# 4  Headstrong Thomas Dunson starts a thriving Tex...          1948
#
#   age_certification  runtime  \
# 0                PG      130
# 1               NaN       69
# 2               NaN       92
# 3             TV-PG       19
# 4               NaN      133
#
#                                               genres production_countries  \
# 0  ['drama', 'family', 'fantasy', 'romance', 'com...               ['US']
# 1                                  ['comedy', 'war']               ['US']
# 2                     ['drama', 'romance', 'comedy']               ['US']
# 3                               ['comedy', 'family']               ['US']
# 4          ['western', 'drama', 'romance', 'action']               ['US']
#
#    seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 0      NaN  tt0038650         8.6    467766.0           27.611       8.261
# 1      NaN  tt0023969         7.8     60933.0            9.013       7.357
# 2      NaN  tt0032599         7.8     60244.0           14.759       7.433
# 3     26.0  tt0850645         8.5      1149.0           15.424       7.600
# 4      NaN  tt0040724         7.8     32210.0           12.400       7.400

# %%
titles.shape
# Out:
# (10873, 15)

# %%
titles.describe()
# Out:
#        release_year       runtime      seasons   imdb_score    imdb_votes  \
# count  10873.000000  10873.000000  1551.000000  9765.000000  9.753000e+03
# mean    2004.077807     85.869033     2.661509     5.970558  8.973232e+03
# std       24.883711     34.156332     3.719633     1.362815  4.897767e+04
# min     1912.000000      0.000000     1.000000     1.100000  5.000000e+00
# 25%     2002.000000     65.000000     1.000000     5.100000  1.190000e+02
# 50%     2015.000000     89.000000     1.000000     6.100000  4.880000e+02
# 75%     2019.000000    102.000000     3.000000     7.000000  2.493000e+03
# max     2023.000000    940.000000    53.000000     9.900000  2.081757e+06
#
#        tmdb_popularity   tmdb_score
# count     10302.000000  8747.000000
# mean          7.614083     5.977729
# std          45.845289     1.512941
# min           0.000153     0.500000
# 25%           1.327250     5.066500
# 50%           2.658500     6.000000
# 75%           6.185000     6.983000
# max        3187.531000    10.000000

# %%
titles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10873 entries, 0 to 10872
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10873 non-null  object
#  1   title                 10873 non-null  object
#  2   type                  10873 non-null  object
#  3   description           10729 non-null  object
#  4   release_year          10873 non-null  int64
#  5   age_certification     3688 non-null   object
#  6   runtime               10873 non-null  int64
#  7   genres                10873 non-null  object
#  8   production_countries  10873 non-null  object
#  9   seasons               1551 non-null   float64
#  10  imdb_id               10172 non-null  object
#  11  imdb_score            9765 non-null   float64
#  12  imdb_votes            9753 non-null   float64
#  13  tmdb_popularity       10302 non-null  float64
#  14  tmdb_score            8747 non-null   float64
# dtypes: float64(5), int64(2), object(8)
# memory usage: 1.2+ MB

# %%
credits = pd.read_csv("credits.csv")

# %%
credits.head()
# Out:
#    person_id       id              name      character   role
# 0      25020  tm87233     James Stewart  George Bailey  ACTOR
# 1      26190  tm87233        Donna Reed     Mary Hatch  ACTOR
# 2      25653  tm87233  Lionel Barrymore     Mr. Potter  ACTOR
# 3      13301  tm87233   Thomas Mitchell    Uncle Billy  ACTOR
# 4      34171  tm87233     Henry Travers       Clarence  ACTOR

# %% [markdown]
# # Data Cleaning

# %%
titles.duplicated().sum()
# Out:
# 0

# %% [markdown]
# There are zero duplicates in our dataset. Our dataset is clean and it is important to remove unnecessary columns and null values.

# %%
# we have removed the columns which would not play any role in our data analysis
titles.drop(['description', 'imdb_id', 'imdb_votes'], axis=1, inplace = True)

# %%
titles.shape
# Out:
# (10873, 12)

# %%
titles.isnull().sum()
# Out:
# id                         0
# title                      0
# type                       0
# release_year               0
# age_certification       7185
# runtime                    0
# genres                     0
# production_countries       0
# seasons                 9322
# imdb_score              1108
# tmdb_popularity          571
# tmdb_score              2126
# dtype: int64

# %%
# we will fill the null values with 0
titles.fillna(0,inplace=True)

# %%
titles.isnull().sum()
# Out:
# id                      0
# title                   0
# type                    0
# release_year            0
# age_certification       0
# runtime                 0
# genres                  0
# production_countries    0
# seasons                 0
# imdb_score              0
# tmdb_popularity         0
# tmdb_score              0
# dtype: int64

# %%
titles.head()
# Out:
#          id                  title   type  release_year age_certification  \
# 0   tm87233  It's a Wonderful Life  MOVIE          1946                PG
# 1  tm143047              Duck Soup  MOVIE          1933                 0
# 2   tm83884        His Girl Friday  MOVIE          1940                 0
# 3   ts20945      The Three Stooges   SHOW          1934             TV-PG
# 4    tm5012              Red River  MOVIE          1948                 0
#
#    runtime                                             genres  \
# 0      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 1       69                                  ['comedy', 'war']
# 2       92                     ['drama', 'romance', 'comedy']
# 3       19                               ['comedy', 'family']
# 4      133          ['western', 'drama', 'romance', 'action']
#
#   production_countries  seasons  imdb_score  tmdb_popularity  tmdb_score
# 0               ['US']      0.0         8.6           27.611       8.261
# 1               ['US']      0.0         7.8            9.013       7.357
# 2               ['US']      0.0         7.8           14.759       7.433
# 3               ['US']     26.0         8.5           15.424       7.600
# 4               ['US']      0.0         7.8           12.400       7.400

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# After cleaning the data, we need to explore it and find out insights from the data.

# %%
# Let us first analyse the production of movies or shows by countries
countries = titles[['title','production_countries']]
countries.head()
# Out:
#                    title production_countries
# 0  It's a Wonderful Life               ['US']
# 1              Duck Soup               ['US']
# 2        His Girl Friday               ['US']
# 3      The Three Stooges               ['US']
# 4              Red River               ['US']

# %%
countries.set_index('production_countries', inplace=True)
countries=countries.drop('[]')

# %%
countries=countries.reset_index()

# %%
countries
# Out:
#       production_countries                  title
# 0                   ['US']  It's a Wonderful Life
# 1                   ['US']              Duck Soup
# 2                   ['US']        His Girl Friday
# 3                   ['US']      The Three Stooges
# 4                   ['US']              Red River
# ...                    ...                    ...
# 10192               ['US']   Work It Out Wombats!
# 10193               ['ES']   Marc Marquez: ALL IN
# 10194               ['JP']                    A2Z
# 10195               ['IN']                   Hunt
# 10196               ['IN']     Ennalum Ente Aliya
#
# [10197 rows x 2 columns]

# %%
for i in countries['production_countries']:
    print(type(i))
    break;
# Out:
# <class 'str'>

# %%
for i in range(len(countries["production_countries"])):
    in_list = countries["production_countries"][i]
    res = in_list.strip('][').split(', ')
    countries["production_countries"][i]=res

# %%
countries['production_countries'][5573]
# Out:
# ["'US'"]

# %%
countries.production_countries.apply(pd.Series)
# Out:
#           0    1    2    3    4    5    6    7    8
# 0      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...
# 10192  'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10193  'ES'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10194  'JP'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10195  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 10196  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
# [10197 rows x 9 columns]

# %%
countries.production_countries.apply(pd.Series).merge(countries, right_index = True, left_index = True)
# Out:
#           0    1    2    3    4    5    6    7    8 production_countries  \
# 0      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# 1      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# 2      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# 3      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# 4      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...                  ...
# 10192  'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['US']
# 10193  'ES'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['ES']
# 10194  'JP'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['JP']
# 10195  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['IN']
# 10196  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN               ['IN']
#
#                        title
# 0      It's a Wonderful Life
# 1                  Duck Soup
# 2            His Girl Friday
# 3          The Three Stooges
# 4                  Red River
# ...                      ...
# 10192   Work It Out Wombats!
# 10193   Marc Marquez: ALL IN
# 10194                    A2Z
# 10195                   Hunt
# 10196     Ennalum Ente Aliya
#
# [10197 rows x 11 columns]

# %%
countries.production_countries.apply(pd.Series).\
merge(countries, right_index = True, left_index = True).\
drop(["production_countries"], axis = 1)
# Out:
#           0    1    2    3    4    5    6    7    8                  title
# 0      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  It's a Wonderful Life
# 1      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN              Duck Soup
# 2      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        His Girl Friday
# 3      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN      The Three Stooges
# 4      'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN              Red River
# ...     ...  ...  ...  ...  ...  ...  ...  ...  ...                    ...
# 10192  'US'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   Work It Out Wombats!
# 10193  'ES'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN   Marc Marquez: ALL IN
# 10194  'JP'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                    A2Z
# 10195  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN                   Hunt
# 10196  'IN'  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN     Ennalum Ente Aliya
#
# [10197 rows x 10 columns]

# %%
countries.production_countries.apply(pd.Series).\
merge(countries, right_index = True, left_index = True).\
drop(["production_countries"], axis = 1)\
.melt(id_vars = ['title'], value_name = "production_countries")
# Out:
#                        title variable production_countries
# 0      It's a Wonderful Life        0                 'US'
# 1                  Duck Soup        0                 'US'
# 2            His Girl Friday        0                 'US'
# 3          The Three Stooges        0                 'US'
# 4                  Red River        0                 'US'
# ...                      ...      ...                  ...
# 91768   Work It Out Wombats!        8                  NaN
# 91769   Marc Marquez: ALL IN        8                  NaN
# 91770                    A2Z        8                  NaN
# 91771                   Hunt        8                  NaN
# 91772     Ennalum Ente Aliya        8                  NaN
#
# [91773 rows x 3 columns]

# %%
new_df_1=countries.production_countries.apply(pd.Series).\
merge(countries, right_index = True, left_index = True).\
drop(["production_countries"], axis = 1)\
.melt(id_vars = ['title'], value_name = "production_countries")\
.drop("variable", axis = 1).dropna()

new_df_1.head()
# Out:
#                    title production_countries
# 0  It's a Wonderful Life                 'US'
# 1              Duck Soup                 'US'
# 2        His Girl Friday                 'US'
# 3      The Three Stooges                 'US'
# 4              Red River                 'US'

# %%
new_df_1['production_countries'].value_counts()
# Out:
# 'US'    6027
# 'IN'    1165
# 'GB'    1009
# 'CA'     648
# 'FR'     330
#         ...
# 'MK'       1
# 'RW'       1
# 'CF'       1
# 'SO'       1
# 'HR'       1
# Name: production_countries, Length: 128, dtype: int64

# %%
top_10_countries = new_df_1.production_countries.value_counts().head(10)

# %%
top_10_countries.plot(kind = 'bar', width =0.8, figsize=(9, 6))
plt.title('Top 10 countries with highest production')
plt.xlabel('Countries')
plt.ylabel('Production count')
plt.show()

# %% [markdown]
# From the graph showing the top 10 countries, 'US' has the highest number of production followed by 'IN'

# %%
year_count = titles.release_year.value_counts()
year_count
# Out:
# 2021    1140
# 2020     878
# 2019     864
# 2018     757
# 2017     618
#         ...
# 1923       3
# 1916       2
# 1913       1
# 1912       1
# 1917       1
# Name: release_year, Length: 112, dtype: int64

# %%
sns.lineplot(data= year_count)
sns.set(rc={'figure.figsize':(100,8.27)})
plt.title('Total shows/movies released over the years')
plt.xlim(1950, 2025)
plt.xlabel('release year')
plt.ylabel('total')
plt.show()

# %% [markdown]
# The line graph shows a huge increase in production between 2010 and 2020. There has also been a great decrease in production from 2020 till date.

# %%
data = titles.merge(credits, how = 'outer', on= 'id')
data.head()
# Out:
#         id                  title   type  release_year age_certification  \
# 0  tm87233  It's a Wonderful Life  MOVIE          1946                PG
# 1  tm87233  It's a Wonderful Life  MOVIE          1946                PG
# 2  tm87233  It's a Wonderful Life  MOVIE          1946                PG
# 3  tm87233  It's a Wonderful Life  MOVIE          1946                PG
# 4  tm87233  It's a Wonderful Life  MOVIE          1946                PG
#
#    runtime                                             genres  \
# 0      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 1      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 2      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 3      130  ['drama', 'family', 'fantasy', 'romance', 'com...
# 4      130  ['drama', 'family', 'fantasy', 'romance', 'com...
#
#   production_countries  seasons  imdb_score  tmdb_popularity  tmdb_score  \
# 0               ['US']      0.0         8.6           27.611       8.261
# 1               ['US']      0.0         8.6           27.611       8.261
# 2               ['US']      0.0         8.6           27.611       8.261
# 3               ['US']      0.0         8.6           27.611       8.261
# 4               ['US']      0.0         8.6           27.611       8.261
#
#    person_id              name      character   role
# 0    25020.0     James Stewart  George Bailey  ACTOR
# 1    26190.0        Donna Reed     Mary Hatch  ACTOR
# 2    25653.0  Lionel Barrymore     Mr. Potter  ACTOR
# 3    13301.0   Thomas Mitchell    Uncle Billy  ACTOR
# 4    34171.0     Henry Travers       Clarence  ACTOR

# %%
director = data[data['role'] == 'DIRECTOR']
director.head()
# Out:
#            id                        title   type  release_year  \
# 115   tm87233        It's a Wonderful Life  MOVIE          1946
# 150  tm143047                    Duck Soup  MOVIE          1933
# 186   tm83884              His Girl Friday  MOVIE          1940
# 227    tm5012                    Red River  MOVIE          1948
# 259   tm82253  The Best Years of Our Lives  MOVIE          1947
#
#     age_certification  runtime  \
# 115                PG      130
# 150                 0       69
# 186                 0       92
# 227                 0      133
# 259                 0      171
#
#                                                 genres production_countries  \
# 115  ['drama', 'family', 'fantasy', 'romance', 'com...               ['US']
# 150                                  ['comedy', 'war']               ['US']
# 186                     ['drama', 'romance', 'comedy']               ['US']
# 227          ['western', 'drama', 'romance', 'action']               ['US']
# 259                        ['drama', 'romance', 'war']               ['US']
#
#      seasons  imdb_score  tmdb_popularity  tmdb_score  person_id  \
# 115      0.0         8.6           27.611       8.261    20177.0
# 150      0.0         7.8            9.013       7.357    60962.0
# 186      0.0         7.8           14.759       7.433    23839.0
# 227      0.0         7.8           12.400       7.400    23839.0
# 259      0.0         8.1           16.056       7.838    13717.0
#
#               name character      role
# 115    Frank Capra       NaN  DIRECTOR
# 150    Leo McCarey       NaN  DIRECTOR
# 186   Howard Hawks       NaN  DIRECTOR
# 227   Howard Hawks       NaN  DIRECTOR
# 259  William Wyler       NaN  DIRECTOR

# %%
top_10_director = director.sort_values(['tmdb_score','tmdb_popularity'], ascending = False)[['name', 'tmdb_score','tmdb_popularity']].head(10)
top_10_director
# Out:
#                        name  tmdb_score  tmdb_popularity
# 136443          Sun Kai Kai        10.0            9.687
# 117799  Raymond Lee Wai-Man        10.0            7.478
# 117800        Cha Chuen-Yee        10.0            7.478
# 135112         Kel Thompson        10.0            4.439
# 137198        Nathan Shepka        10.0            3.577
# 134672    Michael Sean Hall        10.0            2.996
# 119619       Brandon Bergin        10.0            2.729
# 61162      Theresa Demarest        10.0            2.652
# 137821          Ryan Pollin        10.0            2.607
# 135756       Steven Durgarn        10.0            2.540

# %%
top_10_director.plot(kind= 'bar', y = 'tmdb_popularity', x = 'name', figsize= (9,6), color= 'green')
plt.xlabel('name')
plt.ylabel('tmdb popularity')
plt.title('Top 10 directors based on tmdb popularity')
plt.show()

# %%
type_count = titles.type.value_counts()
type_count.head()
# Out:
# MOVIE    9322
# SHOW     1551
# Name: type, dtype: int64

# %%
type_count.plot(kind= 'pie', figsize=(10, 5), autopct= '%.2f%%')
plt.title('Type distribution')
plt.show()

# %%
top_10_based_on_tmdb_rating = titles.sort_values(['tmdb_score', 'tmdb_popularity'], ascending= False)[['title','tmdb_score','tmdb_popularity', 'type']].head(10)
top_10_based_on_tmdb_rating
# Out:
#                                   title  tmdb_score  tmdb_popularity   type
# 10096       Time Flies and You Are Here        10.0            9.687   SHOW
# 8349                    Flying Tiger II        10.0            7.478   SHOW
# 6862                     Let's Go Luna!        10.0            7.057   SHOW
# 2270   The Wubbulous World of Dr. Seuss        10.0            5.961   SHOW
# 9970             The Terrible Adventure        10.0            4.439  MOVIE
# 4875                     Tenkai Knights        10.0            4.296   SHOW
# 6893                    Rainbow Rangers        10.0            3.809   SHOW
# 4480                      A Chef's Life        10.0            3.722   SHOW
# 10149                       Do, Re & Mi        10.0            3.713   SHOW
# 10155                    Holiday Monday        10.0            3.577  MOVIE

# %%
top_10_based_on_tmdb_rating.plot(kind='barh', x = 'title', y = 'tmdb_popularity', figsize=(9, 6), color = 'purple')
plt.title('Top 10 based on tmdb votes')
plt.xlabel('tmdb_popularity')
plt.ylabel('Title')
plt.show()

# %%
titles_new=pd.read_csv("titles.csv")
shows = titles_new[titles_new['type'] == "SHOW"]
shows = shows.dropna(subset=['imdb_id','imdb_score','imdb_votes','tmdb_popularity','tmdb_score','description'])

# %%
genres_df=shows[['id','genres']]
genres_df
# Out:
#              id                                             genres
# 3       ts20945                               ['comedy', 'family']
# 5       ts37076                                         ['comedy']
# 247     ts55748                              ['reality', 'family']
# 939      ts3386  ['scifi', 'action', 'crime', 'romance', 'thril...
# 940     ts42867                     ['family', 'fantasy', 'music']
# ...         ...                                                ...
# 10841  ts365330                                  ['documentation']
# 10842  ts369924                              ['comedy', 'reality']
# 10845  ts363288                                ['drama', 'action']
# 10857  ts379207                                ['comedy', 'drama']
# 10865  ts382337                                  ['documentation']
#
# [1094 rows x 2 columns]

# %%
genres_df.set_index('genres',inplace=True)

# %%
genres_df=genres_df.drop('[]')

# %%
genres_df=genres_df.reset_index()

# %%
for i in range(len(genres_df['genres'])):
    ini_list = genres_df['genres'][i]
    res = ini_list.strip('][').split(', ')
    genres_df['genres'][i]=res

# %%
new_df_2=genres_df.genres.apply(pd.Series).\
merge(genres_df, right_index = True, left_index = True).\
drop(["genres"], axis = 1)\
.melt(id_vars = ['id'], value_name = "genres")\
.drop("variable", axis = 1).dropna()

# %%
new_df_2.head(5)
# Out:
#         id     genres
# 0  ts20945   'comedy'
# 1  ts37076   'comedy'
# 2  ts55748  'reality'
# 3   ts3386    'scifi'
# 4  ts42867   'family'

# %%
new_df_2['genres'].value_counts()
# Out:
# 'drama'            564
# 'comedy'           431
# 'animation'        244
# 'action'           208
# 'family'           205
# 'scifi'            190
# 'thriller'         175
# 'romance'          175
# 'fantasy'          170
# 'documentation'    167
# 'crime'            163
# 'reality'           98
# 'european'          94
# 'history'           78
# 'horror'            63
# 'sport'             50
# 'war'               43
# 'music'             30
# 'western'           13
# Name: genres, dtype: int64

# %%
Most_common_genres = new_df_2.genres.value_counts()

# object to df
Most_common_genres = pd.DataFrame(Most_common_genres)

# change column titles
Most_common_genres.rename(columns = {'genres':'total_shows'}, inplace = True)

# filter top 10 values. 
top_10_genres= Most_common_genres.head(10)

# %%
Most_common_genres.head()
# Out:
#              total_shows
# 'drama'              564
# 'comedy'             431
# 'animation'          244
# 'action'             208
# 'family'             205

# %%
plt.figure(figsize=(15,9))

# Bar chart 
top_10_genres_plot = sns.barplot(x=top_10_genres.index, y=top_10_genres['total_shows'], data=top_10_genres, ci=None)
plt.title('10 most common genres')
plt.xlabel('genres')
plt.ylabel('Production count')

plt.show()

# %%
shows.plot(kind='scatter',x='seasons',y='tmdb_popularity',figsize=(12,6),color='red')
plt.xlabel('seasons')
plt.ylabel('tmdb_popularity')
plt.title('tmdb_popularity v/s seasons')
plt.show()

# %% [markdown]
# from the graph we can see that shows which have low popularity have less seasons.
# correlation is higher where popularity is low.
